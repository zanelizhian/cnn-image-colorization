# %%
# Plot ad hoc CIFAR10 instances
from __future__ import print_function
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import numpy as np
import matplotlib.pyplot as plt

from skimage import data
from skimage.color import rgb2gray

# %%
# Running on an Quadro RTX 4000 (Similar to RTX 2070) Set memory limit else it is out of memory
gpus= tf.config.list_physical_devices('GPU') 
print(gpus)
tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## (a)

# %%
# load data
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()
# create a grid of 3x3 images

print(y_train.shape)
index_bird_train = np.where(y_train == 2)
index_bird_test = np.where(y_test == 2)
# Out:
# (50000, 1)

# %% [markdown]
# ## (b)

# %%
X_train = X_train[index_bird_train[0]]
y_train = y_train[index_bird_train[0]]
X_test = X_test[index_bird_test[0]]
y_test = y_test[index_bird_test[0]]

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# X_train = np.append(X_train,X_test,axis=0)
# y_train = np.append(y_train,y_test,axis=0)
# Out:
# (5000, 32, 32, 3)
# (5000, 1)
# (1000, 32, 32, 3)
# (1000, 1)

# %%
for i in range(0, 9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X_train[i])
    plt.show()

# %% [markdown]
# ## (c)

# %% [markdown]
# I would select all the pixels in K-mean (P = 6144000)

# %% [markdown]
# ## (d)
# In this section, I first run k-means clustering on a single image to test the algorithm. Then I run k-means clustering on all (6144000) pixels.

# %%
class KMeans:
    def __init__(self, n_cluster, max_iter=100, e=0.0001):
        self.n_cluster = n_cluster
        self.max_iter = max_iter
        self.e = e
    
    def fit_opt(self, x):
        np.random.seed(42)
        N, D = x.shape
        centroids = x[np.random.choice(len(x), self.n_cluster)]
        gamma = np.zeros(N)
        sse = None
        
        for i in range(self.max_iter):
            # Assign each data point to nearest centroid
            distance = ((np.reshape(x, (N, 1, D)) -  centroids) ** 2).sum(axis=2)
            gamma = np.argmin(distance, axis=1)
            
            # Computer SSE to check for convergence
            sse_new = ((x - centroids[gamma.astype(int)]) ** 2).sum() / N
            if sse is None:
                sse = sse_new
            elif abs(sse_new - sse) < self.e:
                break
            else:
                sse = sse_new
            
            # Compute new centroids as mean of data points in each cluster
            centroids_new = np.zeros((self.n_cluster, D))

            for centroid_ind in range(self.n_cluster):
                cluster_data = x[gamma == centroid_ind]
                if(cluster_data.size != 0):
                    centroids_new[centroid_ind] = cluster_data.mean(axis=0)
                else:
                    centroids_new[centroid_ind] = centroids[np.random.randint(self.n_cluster, size=1)]
                
            centroids = centroids_new
            
        return centroids, i + 1

# %%
def get_k_means_plus_plus_center_indices(n, n_cluster, x, generator=np.random):
    '''
    :param n: number of samples in the data
    :param n_cluster: the number of cluster centers required
    :param x: data - numpy array of points
    :param generator: random number generator. Use it in the same way as np.random.

    :return: the center points array of length n_clusters with each entry being the *index* of a sample
             chosen as centroid.
    '''
    centers = []
    initial = generator.randint(0, n)
    centers.append(initial)
    prob = np.zeros(n)
    for k in range(1, n_cluster):
        i = 0
        for data in x:
            prob[i] = np.min([float(np.linalg.norm(data - x[centers[j]]) ** 2) for j in range(k)])
            i += 1
        prob = prob / sum(prob)
        r = generator.rand()
        m = 0
        while r > 0:
            r -= prob[m]
            m += 1
        centers.append(m - 1)
    return centers

# %%
im = X_train[0].copy()

# %%
def transform_image(image, centroids):
    N, M = image.shape[:2]
    distances = ((np.reshape(image, (N, M, 1, 3)) - centroids) ** 2).sum(axis = 3)
    centroid_indices = np.argmin(distances, axis=2)
    
    return centroids[centroid_indices]

# %%
plt.imshow(im)

# %%
im.astype(np.float32)
# Out:
# array([[[164., 206.,  84.],
#         [105., 140.,  61.],
#         [118., 148., 101.],
#         ...,
#         [109., 147.,  73.],
#         [108., 147.,  69.],
#         [ 91., 129.,  57.]],
#
#        [[167., 213.,  84.],
#         [116., 160.,  49.],
#         [ 72., 109.,  43.],
#         ...,
#         [105., 142.,  79.],
#         [105., 142.,  72.],
#         [ 89., 127.,  57.]],
#
#        [[140., 191.,  65.],
#         [142., 193.,  66.],
#         [119., 163.,  79.],
#         ...,
#         [104., 139.,  84.],
#         [ 84., 120.,  58.],
#         [ 78., 115.,  49.]],
#
#        ...,
#
#        [[139., 148.,  81.],
#         [142., 155.,  74.],
#         [135., 156.,  72.],
#         ...,
#         [ 89., 134.,  28.],
#         [ 97., 148.,  24.],
#         [126., 176.,  49.]],
#
#        [[163., 157.,  85.],
#         [153., 164.,  82.],
#         [146., 164.,  90.],
#         ...,
#         [ 85., 130.,  19.],
#         [ 98., 148.,  27.],
#         [127., 178.,  48.]],
#
#        [[183., 153., 102.],
#         [176., 182., 116.],
#         [154., 154., 100.],
#         ...,
#         [ 94., 134.,  29.],
#         [ 91., 133.,  26.],
#         [122., 170.,  44.]]], dtype=float32)

# %%
N, M = im.shape[:2]
data = im.reshape(N * M, 3)
k = 16

k_means = KMeans(k, 1000, 1e-6)
centroids, i = k_means.fit_opt(data)

print('Centroids computed in {} iterations'.format(i))
print(centroids)
im_comp = transform_image(im, centroids)

mse = np.sum((im - im_comp) ** 2) / (N * M)
print('Mean square error: {}\n'.format(mse))

plt.imshow(im_comp.astype(int))
# Out:
# Centroids computed in 29 iterations
# [[159.43636364 180.47272727 167.83636364]
#  [ 37.22727273  52.81818182  38.68181818]
#  [ 56.42857143  77.2244898   96.32653061]
#  [193.03921569 203.43137255 192.09803922]
#  [160.25396825 211.6984127   74.53968254]
#  [ 98.08823529  82.41176471  38.82352941]
#  [129.48351648 181.03296703  59.12087912]
#  [118.08988764 148.7752809   81.16853933]
#  [138.         161.22413793 111.87931034]
#  [155.20547945 196.38356164 105.21917808]
#  [ 92.80952381 121.45238095 143.35714286]
#  [179.97590361 222.21686747 114.03614458]
#  [ 72.57731959 108.3814433   37.57731959]
#  [100.90697674 137.26744186  53.18604651]
#  [ 96.86538462 113.88461538  71.40384615]
#  [101.01754386 155.28070175  31.03508772]]
# Mean square error: 454.6007712058507

# %%
centroids.astype(np.uint8)
# Out:
# array([[159, 180, 167],
#        [ 37,  52,  38],
#        [ 56,  77,  96],
#        [193, 203, 192],
#        [160, 211,  74],
#        [ 98,  82,  38],
#        [129, 181,  59],
#        [118, 148,  81],
#        [138, 161, 111],
#        [155, 196, 105],
#        [ 92, 121, 143],
#        [179, 222, 114],
#        [ 72, 108,  37],
#        [100, 137,  53],
#        [ 96, 113,  71],
#        [101, 155,  31]], dtype=uint8)

# %%
colorful_centroids = np.array([[0,0,128], [230, 25, 75], [170, 255, 195], [255, 255, 255]])

# %%
im_colorful = transform_image(im, colorful_centroids)

mse = np.sum((im - im_colorful) ** 2) / (N * M)
print('Mean square error: {}\n'.format(mse))

plt.imshow(im_colorful.astype(int))
# Out:
# Mean square error: 19307.0712890625

# %% [markdown]
# Note that since I selected all the pixels, it would take a relatively long time to compute. So I store the pre-computed value to accelerate the debugging process. The computation code is commented above

# %%
#X = np.append(X_train,X_test,axis=0)
#N, M, L = X.shape[:3]
#data = X.reshape(N * M * L, 3)
#centroids, _ = k_means.fit_opt(data)
centroids = np.array([[136, 177, 219],
       [122, 143,  69],
       [ 20,  21,  17],
       [202, 185, 138],
       [130, 130, 118],
       [100, 103,  93],
       [ 98,  92,  50],
       [140, 113,  79],
       [208, 212, 211],
       [ 52,  53,  38],
       [243, 244, 242],
       [182, 183, 178],
       [169, 156, 100],
       [ 71,  75,  68],
       [155, 156, 147],
       [ 79, 123, 172]])

# %%
tetrachrome_train = np.empty((X_train.shape), dtype=np.uint8)
tetrachrome_test = np.empty((X_test.shape), dtype=np.uint8)
for i in range(X_train.shape[0]):
    tetrachrome_train[i] = (transform_image(X_train[i], centroids)).astype(np.uint8)
for i in range(X_test.shape[0]):
    tetrachrome_test[i] = (transform_image(X_test[i], centroids)).astype(np.uint8)
    
print(tetrachrome_train.shape)
print(tetrachrome_test.shape)
# Out:
# (5000, 32, 32, 3)
# (1000, 32, 32, 3)

# %%
centroids.astype(np.uint8)
# Out:
# array([[136, 177, 219],
#        [122, 143,  69],
#        [ 20,  21,  17],
#        [202, 185, 138],
#        [130, 130, 118],
#        [100, 103,  93],
#        [ 98,  92,  50],
#        [140, 113,  79],
#        [208, 212, 211],
#        [ 52,  53,  38],
#        [243, 244, 242],
#        [182, 183, 178],
#        [169, 156, 100],
#        [ 71,  75,  68],
#        [155, 156, 147],
#        [ 79, 123, 172]], dtype=uint8)

# %%
plt.imshow(tetrachrome_train[0])

# %%
centroids_encoding = np.identity(k).astype(np.uint8) # identity matrix as encoding
# Calculate the one hot encoded image which is going to be the output of the network. 
def one_hot_encode_image(image, centroids):
    N, M = image.shape[:2]
    distances = ((np.reshape(image, (N, M, 1, 3)) - centroids) ** 2).sum(axis = 3)
    centroid_indices = np.argmin(distances, axis=2)
    
    return centroids_encoding[centroid_indices]

# %%
N, M = X_train.shape[1:3]
one_hot_encoded_train = np.empty([X_train.shape[0], N, M, k], dtype=np.uint8)
one_hot_encoded_test = np.empty([X_test.shape[0], N, M, k], dtype=np.uint8)

for i in range(X_train.shape[0]):
    one_hot_encoded_train[i] = (one_hot_encode_image(X_train[i], centroids)).astype(np.uint8)
for i in range(X_test.shape[0]):
    one_hot_encoded_test[i] = (one_hot_encode_image(X_test[i], centroids)).astype(np.uint8)
    
print(one_hot_encoded_train.shape)
print(one_hot_encoded_test.shape)
# Out:
# (5000, 32, 32, 16)
# (1000, 32, 32, 16)

# %%
# Check if it is same as above
plt.imshow(np.dot(one_hot_encoded_train[0], centroids.astype(np.uint8)))

# %%
one_hot_encoded_train[0].shape
# Out:
# (32, 32, 16)

# %% [markdown]
# ## (e)

# %%
grayscale_img = rgb2gray(im)

# %%
(grayscale_img * 255).astype(np.uint8)
# Out:
# array([[188, 126, 138, ..., 133, 133, 115],
#        [193, 142,  96, ..., 129, 129, 113],
#        [171, 173, 147, ..., 127, 107, 102],
#        ...,
#        [141, 146, 145, ..., 116, 128, 156],
#        [153, 155, 154, ..., 112, 128, 157],
#        [155, 175, 150, ..., 117, 116, 150]], dtype=uint8)

# %%
plt.imshow((grayscale_img * 255).astype(np.uint8), cmap=plt.cm.gray)

# %%
grayscale_img = rgb2gray(im)

# %%
grayscale_train = np.empty((X_train.shape[:3]), dtype=np.uint8)
grayscale_test = np.empty((X_test.shape[:3]), dtype=np.uint8)

# %%
print(grayscale_train.shape)
print(grayscale_test.shape)
# Out:
# (5000, 32, 32)
# (1000, 32, 32)

# %%
for i in range(X_train.shape[0]):
    grayscale_img = rgb2gray(X_train[i])
    grayscale_train[i] = (grayscale_img * 255).astype(np.uint8)
    
for i in range(X_test.shape[0]):
    grayscale_img = rgb2gray(X_test[i])
    grayscale_test[i] = (grayscale_img * 255).astype(np.uint8)

# %%
plt.imshow(grayscale_train[7], cmap=plt.cm.gray)

# %% [markdown]
# ## (f)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (5, 5), activation='relu', padding='same', input_shape=(32, 32, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (5, 5), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (5, 5), activation='relu', padding='same'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          102464
# =================================================================
# Total params: 154,560
# Trainable params: 154,560
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(2048, activation='relu'))
model.add(layers.Dense(2048, activation='relu'))
model.add(layers.Dense(1024*k, activation='relu'))
model.add(layers.Reshape((1024, k), input_shape=(1024*k,)))
model.add(layers.Softmax())

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          102464
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              8390656
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dense_2 (Dense)              (None, 16384)             33570816
# _________________________________________________________________
# reshape (Reshape)            (None, 1024, 16)          0
# _________________________________________________________________
# softmax (Softmax)            (None, 1024, 16)          0
# =================================================================
# Total params: 46,312,384
# Trainable params: 46,312,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

grayscale_train = grayscale_train.reshape(5000, 32, 32, 1)
grayscale_test = grayscale_test.reshape(1000, 32, 32, 1)

one_hot_encoded_train = one_hot_encoded_train.reshape(5000, 1024, k)
one_hot_encoded_test = one_hot_encoded_test.reshape(1000, 1024, k)

history = model.fit(grayscale_train, one_hot_encoded_train, epochs=30, validation_data=(grayscale_test, one_hot_encoded_test))
# Out:
# Epoch 1/30
# 157/157 [==============================] - 3s 12ms/step - loss: 2.7649 - accuracy: 0.0997 - val_loss: 2.7100 - val_accuracy: 0.1246
# Epoch 2/30
# 157/157 [==============================] - 2s 10ms/step - loss: 2.6928 - accuracy: 0.1351 - val_loss: 2.6721 - val_accuracy: 0.1436
# Epoch 3/30
# 157/157 [==============================] - 2s 10ms/step - loss: 2.6444 - accuracy: 0.1567 - val_loss: 2.6430 - val_accuracy: 0.1567
# Epoch 4/30
# 157/157 [==============================] - 2s 10ms/step - loss: 2.6142 - accuracy: 0.1706 - val_loss: 2.6164 - val_accuracy: 0.1683
# Epoch 5/30
# 157/157 [==============================] - 2s 10ms/step - loss: 2.5894 - accuracy: 0.1815 - val_loss: 2.6089 - val_accuracy: 0.1728
# Epoch 6/30
# 157/157 [==============================] - 2s 10ms/step - loss: 2.5611 - accuracy: 0.1937 - val_loss: 2.5999 - val_accuracy: 0.1762
# Epoch 7/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.5460 - accuracy: 0.1995 - val_loss: 2.5825 - val_accuracy: 0.1834
# Epoch 8/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.5220 - accuracy: 0.2094 - val_loss: 2.5764 - val_accuracy: 0.1864
# Epoch 9/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.5048 - accuracy: 0.2157 - val_loss: 2.5750 - val_accuracy: 0.1866
# Epoch 10/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.4900 - accuracy: 0.2224 - val_loss: 2.5649 - val_accuracy: 0.1906
# Epoch 11/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.4673 - accuracy: 0.2310 - val_loss: 2.5690 - val_accuracy: 0.1885
# Epoch 12/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.4519 - accuracy: 0.2371 - val_loss: 2.5704 - val_accuracy: 0.1917
# Epoch 13/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.4296 - accuracy: 0.2447 - val_loss: 2.5656 - val_accuracy: 0.1931
# Epoch 14/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.4035 - accuracy: 0.2537 - val_loss: 2.5735 - val_accuracy: 0.1922
# Epoch 15/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.3865 - accuracy: 0.2590 - val_loss: 2.5819 - val_accuracy: 0.1916
# Epoch 16/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.3722 - accuracy: 0.2639 - val_loss: 2.5961 - val_accuracy: 0.1878
# Epoch 17/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.3517 - accuracy: 0.2705 - val_loss: 2.5915 - val_accuracy: 0.1902
# Epoch 18/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.3286 - accuracy: 0.2779 - val_loss: 2.6067 - val_accuracy: 0.1865
# Epoch 19/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.3078 - accuracy: 0.2837 - val_loss: 2.5979 - val_accuracy: 0.1916
# Epoch 20/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.2840 - accuracy: 0.2911 - val_loss: 2.6039 - val_accuracy: 0.1885
# Epoch 21/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.2657 - accuracy: 0.2960 - val_loss: 2.6362 - val_accuracy: 0.1880
# Epoch 22/30
# 157/157 [==============================] - 2s 10ms/step - loss: 2.2335 - accuracy: 0.3063 - val_loss: 2.6450 - val_accuracy: 0.1856
# Epoch 23/30
# 157/157 [==============================] - 2s 10ms/step - loss: 2.2205 - accuracy: 0.3101 - val_loss: 2.6751 - val_accuracy: 0.1842
# Epoch 24/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.2044 - accuracy: 0.3142 - val_loss: 2.6679 - val_accuracy: 0.1853
# Epoch 25/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.1907 - accuracy: 0.3175 - val_loss: 2.6788 - val_accuracy: 0.1822
# Epoch 26/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.1554 - accuracy: 0.3270 - val_loss: 2.6961 - val_accuracy: 0.1823
# Epoch 27/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.1365 - accuracy: 0.3329 - val_loss: 2.7210 - val_accuracy: 0.1796
# Epoch 28/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.1193 - accuracy: 0.3378 - val_loss: 2.7274 - val_accuracy: 0.1769
# Epoch 29/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.0952 - accuracy: 0.3433 - val_loss: 2.7505 - val_accuracy: 0.1729
# Epoch 30/30
# 157/157 [==============================] - 2s 11ms/step - loss: 2.0945 - accuracy: 0.3428 - val_loss: 2.7688 - val_accuracy: 0.1752

# %%
plt.plot(1 - np.array(history.history['accuracy']), label='Train_error')
plt.plot(1 - np.array(history.history['val_accuracy']), label = 'val_error')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %% [markdown]
# From the graph we can see that training error decreased continously, while the validation error stopped at around 0.80 after 15 epochs. Now we are going to compare the artificially colored versions of the first 10 images in the test set.

# %%
prediction = model.predict(grayscale_test.reshape(1000, 32, 32, 1))

# %%
prediction = prediction.reshape(1000, 32, 32, k)

# %%
one_hot_encoded_test = one_hot_encoded_test.reshape(1000, 32, 32, k)

# %%
for i in range(0, 9):
    plt.figure(figsize=(20,20))
    plt.subplot(10, 3, 3*i+1)
    plt.imshow(np.dot(prediction[i], centroids).astype(np.uint8))
    plt.subplot(10, 3, 3*i+2)
    plt.imshow(np.dot(one_hot_encoded_test[i], centroids.astype(np.uint8)))
    plt.subplot(10, 3, 3*i+3)
    plt.imshow(X_test[i])
    plt.show()

# %% [markdown]
# From the graph we can see that the artificially colored versions doesn't not maintained the shape of the object well. (worse than k = 4). The tetrachrome image would look better setting, but the colored image still only captures the grayness in the image. It is seems to only capture the color of the center of the image.
