# %%
# Plot ad hoc CIFAR10 instances
from __future__ import print_function
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import numpy as np
import matplotlib.pyplot as plt

from skimage import data
from skimage.color import rgb2gray

# %%
# Running on an Quadro RTX 4000 (Similar to RTX 2070) Set memory limit else it is out of memory
gpus= tf.config.list_physical_devices('GPU') 
print(gpus)
tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## (a)

# %%
# load data
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()
# create a grid of 3x3 images

print(y_train.shape)
index_bird_train = np.where(y_train == 2)
index_bird_test = np.where(y_test == 2)
# Out:
# (50000, 1)

# %% [markdown]
# ## (b)

# %%
X_train = X_train[index_bird_train[0]]
y_train = y_train[index_bird_train[0]]
X_test = X_test[index_bird_test[0]]
y_test = y_test[index_bird_test[0]]

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# X_train = np.append(X_train,X_test,axis=0)
# y_train = np.append(y_train,y_test,axis=0)
# Out:
# (5000, 32, 32, 3)
# (5000, 1)
# (1000, 32, 32, 3)
# (1000, 1)

# %%
for i in range(0, 9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X_train[i])
    plt.show()

# %% [markdown]
# ## (c)

# %% [markdown]
# I would select all the pixels in K-mean (P = 6144000)

# %% [markdown]
# ## (d)
# In this section, I first run k-means clustering on a single image to test the algorithm. Then I run k-means clustering on all (6144000) pixels.

# %%
class KMeans:
    def __init__(self, n_cluster, max_iter=100, e=0.0001):
        self.n_cluster = n_cluster
        self.max_iter = max_iter
        self.e = e
    
    def fit_opt(self, x):
        np.random.seed(42)
        N, D = x.shape
        centroids = x[np.random.choice(len(x), self.n_cluster)]
        gamma = np.zeros(N)
        sse = None
        
        for i in range(self.max_iter):
            # Assign each data point to nearest centroid
            distance = ((np.reshape(x, (N, 1, D)) -  centroids) ** 2).sum(axis=2)
            gamma = np.argmin(distance, axis=1)
            
            # Computer SSE to check for convergence
            sse_new = ((x - centroids[gamma.astype(int)]) ** 2).sum() / N
            if sse is None:
                sse = sse_new
            elif abs(sse_new - sse) < self.e:
                break
            else:
                sse = sse_new
            
            # Compute new centroids as mean of data points in each cluster
            centroids_new = np.zeros((self.n_cluster, D))

            for centroid_ind in range(self.n_cluster):
                cluster_data = x[gamma == centroid_ind]
                if(cluster_data.size != 0):
                    centroids_new[centroid_ind] = cluster_data.mean(axis=0)
                else:
                    centroids_new[centroid_ind] = centroids[np.random.randint(self.n_cluster, size=1)]
                
            centroids = centroids_new
            
        return centroids, i + 1

# %%
def get_k_means_plus_plus_center_indices(n, n_cluster, x, generator=np.random):
    '''
    :param n: number of samples in the data
    :param n_cluster: the number of cluster centers required
    :param x: data - numpy array of points
    :param generator: random number generator. Use it in the same way as np.random.

    :return: the center points array of length n_clusters with each entry being the *index* of a sample
             chosen as centroid.
    '''
    centers = []
    initial = generator.randint(0, n)
    centers.append(initial)
    prob = np.zeros(n)
    for k in range(1, n_cluster):
        i = 0
        for data in x:
            prob[i] = np.min([float(np.linalg.norm(data - x[centers[j]]) ** 2) for j in range(k)])
            i += 1
        prob = prob / sum(prob)
        r = generator.rand()
        m = 0
        while r > 0:
            r -= prob[m]
            m += 1
        centers.append(m - 1)
    return centers

# %%
im = X_train[0].copy()

# %%
def transform_image(image, centroids):
    N, M = image.shape[:2]
    distances = ((np.reshape(image, (N, M, 1, 3)) - centroids) ** 2).sum(axis = 3)
    centroid_indices = np.argmin(distances, axis=2)
    
    return centroids[centroid_indices]

# %%
plt.imshow(im)

# %%
im.astype(np.float32)
# Out:
# array([[[164., 206.,  84.],
#         [105., 140.,  61.],
#         [118., 148., 101.],
#         ...,
#         [109., 147.,  73.],
#         [108., 147.,  69.],
#         [ 91., 129.,  57.]],
#
#        [[167., 213.,  84.],
#         [116., 160.,  49.],
#         [ 72., 109.,  43.],
#         ...,
#         [105., 142.,  79.],
#         [105., 142.,  72.],
#         [ 89., 127.,  57.]],
#
#        [[140., 191.,  65.],
#         [142., 193.,  66.],
#         [119., 163.,  79.],
#         ...,
#         [104., 139.,  84.],
#         [ 84., 120.,  58.],
#         [ 78., 115.,  49.]],
#
#        ...,
#
#        [[139., 148.,  81.],
#         [142., 155.,  74.],
#         [135., 156.,  72.],
#         ...,
#         [ 89., 134.,  28.],
#         [ 97., 148.,  24.],
#         [126., 176.,  49.]],
#
#        [[163., 157.,  85.],
#         [153., 164.,  82.],
#         [146., 164.,  90.],
#         ...,
#         [ 85., 130.,  19.],
#         [ 98., 148.,  27.],
#         [127., 178.,  48.]],
#
#        [[183., 153., 102.],
#         [176., 182., 116.],
#         [154., 154., 100.],
#         ...,
#         [ 94., 134.,  29.],
#         [ 91., 133.,  26.],
#         [122., 170.,  44.]]], dtype=float32)

# %%
N, M = im.shape[:2]
data = im.reshape(N * M, 3)
k = 32

k_means = KMeans(k, 1000, 1e-6)
centroids, i = k_means.fit_opt(data)

print('Centroids computed in {} iterations'.format(i))
print(centroids)
im_comp = transform_image(im, centroids)

mse = np.sum((im - im_comp) ** 2) / (N * M)
print('Mean square error: {}\n'.format(mse))

plt.imshow(im_comp.astype(int))
# Out:
# Centroids computed in 34 iterations
# [[121.46666667 126.2         60.73333333]
#  [ 36.02564103  49.69230769  40.66666667]
#  [118.53333333 150.8        111.73333333]
#  [193.19047619 200.76190476 197.78571429]
#  [166.27083333 217.85416667  77.02083333]
#  [134.9375     147.625       73.25      ]
#  [150.02631579 195.23684211  93.05263158]
#  [163.20338983 202.18644068 115.74576271]
#  [153.16666667 157.16666667  99.25      ]
#  [178.15789474 201.13157895 155.52631579]
#  [141.69230769 193.07692308  69.61538462]
#  [134.28       171.72        94.08      ]
#  [ 61.84782609  95.80434783  29.52173913]
#  [145.23809524 163.23809524 128.33333333]
#  [115.21052632  98.31578947  46.89473684]
#  [101.84444444 147.17777778  55.02222222]
#  [104.07407407 140.59259259  77.62962963]
#  [111.07142857 116.07142857  99.14285714]
#  [114.         166.          40.28571429]
#  [115.08695652 138.34782609 153.26086957]
#  [ 97.10714286 154.25        26.28571429]
#  [ 57.48888889  76.33333333  92.24444444]
#  [ 73.57692308 108.65384615 140.65384615]
#  [183.35849057 227.24528302 110.50943396]
#  [115.39285714 151.57142857  84.28571429]
#  [153.04       176.04       182.8       ]
#  [123.         172.09090909  66.        ]
#  [129.17857143 183.75        46.17857143]
#  [ 84.1        126.26        36.98      ]
#  [ 91.55555556  72.77777778  33.44444444]
#  [ 90.89473684 121.31578947  66.84210526]
#  [ 81.30232558 107.90697674  51.04651163]]
# Mean square error: 281.64339857955895

# %%
centroids.astype(np.uint8)
# Out:
# array([[121, 126,  60],
#        [ 36,  49,  40],
#        [118, 150, 111],
#        [193, 200, 197],
#        [166, 217,  77],
#        [134, 147,  73],
#        [150, 195,  93],
#        [163, 202, 115],
#        [153, 157,  99],
#        [178, 201, 155],
#        [141, 193,  69],
#        [134, 171,  94],
#        [ 61,  95,  29],
#        [145, 163, 128],
#        [115,  98,  46],
#        [101, 147,  55],
#        [104, 140,  77],
#        [111, 116,  99],
#        [114, 166,  40],
#        [115, 138, 153],
#        [ 97, 154,  26],
#        [ 57,  76,  92],
#        [ 73, 108, 140],
#        [183, 227, 110],
#        [115, 151,  84],
#        [153, 176, 182],
#        [123, 172,  66],
#        [129, 183,  46],
#        [ 84, 126,  36],
#        [ 91,  72,  33],
#        [ 90, 121,  66],
#        [ 81, 107,  51]], dtype=uint8)

# %%
colorful_centroids = np.array([[0,0,128], [230, 25, 75], [170, 255, 195], [255, 255, 255]])

# %%
im_colorful = transform_image(im, colorful_centroids)

mse = np.sum((im - im_colorful) ** 2) / (N * M)
print('Mean square error: {}\n'.format(mse))

plt.imshow(im_colorful.astype(int))
# Out:
# Mean square error: 19307.0712890625

# %% [markdown]
# Note that since I selected all the pixels, it would take a relatively long time to compute. So I store the pre-computed value to accelerate the debugging process. The computation code is commented above

# %%
#X = np.append(X_train,X_test,axis=0)
#N, M, L = X.shape[:3]
#data = X.reshape(N * M * L, 3)
#centroids, _ = k_means.fit_opt(data)
centroids = np.array([[ 14,  14,  12], [190, 174, 133],
       [ 49,  55,  53],
       [156, 156, 149],
       [117, 141,  85],
       [112, 115, 113],
       [ 69,  95,  39],
       [161, 101,  55],
       [218, 201, 160],
       [ 54, 117, 186],
       [224, 223, 217],
       [179, 177, 169],
       [208, 176,  74],
       [ 59,  92, 123],
       [196, 198, 196],
       [137, 136, 127],
       [145, 128,  96],
       [104, 122,  51],
       [171, 147, 112],
       [ 93,  96,  86],
       [109, 138, 165],
       [ 71,  59,  36],
       [152, 173, 104],
       [148, 173, 199],
       [ 73,  75,  68],
       [121, 107,  80],
       [246, 248, 246],
       [103,  83,  54],
       [107, 164, 224],
       [143, 154,  61],
       [173, 206, 237],
       [ 37,  38,  28]])

# %%
tetrachrome_train = np.empty((X_train.shape), dtype=np.uint8)
tetrachrome_test = np.empty((X_test.shape), dtype=np.uint8)
for i in range(X_train.shape[0]):
    tetrachrome_train[i] = (transform_image(X_train[i], centroids)).astype(np.uint8)
for i in range(X_test.shape[0]):
    tetrachrome_test[i] = (transform_image(X_test[i], centroids)).astype(np.uint8)
    
print(tetrachrome_train.shape)
print(tetrachrome_test.shape)
# Out:
# (5000, 32, 32, 3)
# (1000, 32, 32, 3)

# %%
centroids.astype(np.uint8)
# Out:
# array([[ 14,  14,  12],
#        [190, 174, 133],
#        [ 49,  55,  53],
#        [156, 156, 149],
#        [117, 141,  85],
#        [112, 115, 113],
#        [ 69,  95,  39],
#        [161, 101,  55],
#        [218, 201, 160],
#        [ 54, 117, 186],
#        [224, 223, 217],
#        [179, 177, 169],
#        [208, 176,  74],
#        [ 59,  92, 123],
#        [196, 198, 196],
#        [137, 136, 127],
#        [145, 128,  96],
#        [104, 122,  51],
#        [171, 147, 112],
#        [ 93,  96,  86],
#        [109, 138, 165],
#        [ 71,  59,  36],
#        [152, 173, 104],
#        [148, 173, 199],
#        [ 73,  75,  68],
#        [121, 107,  80],
#        [246, 248, 246],
#        [103,  83,  54],
#        [107, 164, 224],
#        [143, 154,  61],
#        [173, 206, 237],
#        [ 37,  38,  28]], dtype=uint8)

# %%
plt.imshow(tetrachrome_train[0])

# %%
centroids_encoding = np.identity(k).astype(np.uint8) # identity matrix as encoding
# Calculate the one hot encoded image which is going to be the output of the network. 
def one_hot_encode_image(image, centroids):
    N, M = image.shape[:2]
    distances = ((np.reshape(image, (N, M, 1, 3)) - centroids) ** 2).sum(axis = 3)
    centroid_indices = np.argmin(distances, axis=2)
    
    return centroids_encoding[centroid_indices]

# %%
N, M = X_train.shape[1:3]
one_hot_encoded_train = np.empty([X_train.shape[0], N, M, k], dtype=np.uint8)
one_hot_encoded_test = np.empty([X_test.shape[0], N, M, k], dtype=np.uint8)

for i in range(X_train.shape[0]):
    one_hot_encoded_train[i] = (one_hot_encode_image(X_train[i], centroids)).astype(np.uint8)
for i in range(X_test.shape[0]):
    one_hot_encoded_test[i] = (one_hot_encode_image(X_test[i], centroids)).astype(np.uint8)
    
print(one_hot_encoded_train.shape)
print(one_hot_encoded_test.shape)
# Out:
# (5000, 32, 32, 32)
# (1000, 32, 32, 32)

# %%
# Check if it is same as above
plt.imshow(np.dot(one_hot_encoded_train[0], centroids.astype(np.uint8)))

# %%
one_hot_encoded_train[0].shape
# Out:
# (32, 32, 32)

# %% [markdown]
# ## (e)

# %%
grayscale_img = rgb2gray(im)

# %%
(grayscale_img * 255).astype(np.uint8)
# Out:
# array([[188, 126, 138, ..., 133, 133, 115],
#        [193, 142,  96, ..., 129, 129, 113],
#        [171, 173, 147, ..., 127, 107, 102],
#        ...,
#        [141, 146, 145, ..., 116, 128, 156],
#        [153, 155, 154, ..., 112, 128, 157],
#        [155, 175, 150, ..., 117, 116, 150]], dtype=uint8)

# %%
plt.imshow((grayscale_img * 255).astype(np.uint8), cmap=plt.cm.gray)

# %%
grayscale_img = rgb2gray(im)

# %%
grayscale_train = np.empty((X_train.shape[:3]), dtype=np.uint8)
grayscale_test = np.empty((X_test.shape[:3]), dtype=np.uint8)

# %%
print(grayscale_train.shape)
print(grayscale_test.shape)
# Out:
# (5000, 32, 32)
# (1000, 32, 32)

# %%
for i in range(X_train.shape[0]):
    grayscale_img = rgb2gray(X_train[i])
    grayscale_train[i] = (grayscale_img * 255).astype(np.uint8)
    
for i in range(X_test.shape[0]):
    grayscale_img = rgb2gray(X_test[i])
    grayscale_test[i] = (grayscale_img * 255).astype(np.uint8)

# %%
plt.imshow(grayscale_train[7], cmap=plt.cm.gray)

# %% [markdown]
# ## (f)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (5, 5), activation='relu', padding='same', input_shape=(32, 32, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (5, 5), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (5, 5), activation='relu', padding='same'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          102464
# =================================================================
# Total params: 154,560
# Trainable params: 154,560
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(2048, activation='relu'))
model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dense(1024*k, activation='relu'))
model.add(layers.Reshape((1024, k), input_shape=(1024*k,)))
model.add(layers.Softmax())

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          102464
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              8390656
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              8392704
# _________________________________________________________________
# dense_2 (Dense)              (None, 32768)             134250496
# _________________________________________________________________
# reshape (Reshape)            (None, 1024, 32)          0
# _________________________________________________________________
# softmax (Softmax)            (None, 1024, 32)          0
# =================================================================
# Total params: 151,188,416
# Trainable params: 151,188,416
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

grayscale_train = grayscale_train.reshape(5000, 32, 32, 1)
grayscale_test = grayscale_test.reshape(1000, 32, 32, 1)

one_hot_encoded_train = one_hot_encoded_train.reshape(5000, 1024, k)
one_hot_encoded_test = one_hot_encoded_test.reshape(1000, 1024, k)

history = model.fit(grayscale_train, one_hot_encoded_train, epochs=30, validation_data=(grayscale_test, one_hot_encoded_test))
# Out:
# Epoch 1/30
# 157/157 [==============================] - 6s 33ms/step - loss: 3.4675 - accuracy: 0.0595 - val_loss: 3.4164 - val_accuracy: 0.0675
# Epoch 2/30
# 157/157 [==============================] - 5s 30ms/step - loss: 3.3869 - accuracy: 0.0843 - val_loss: 3.3789 - val_accuracy: 0.0891
# Epoch 3/30
# 157/157 [==============================] - 5s 30ms/step - loss: 3.3429 - accuracy: 0.1031 - val_loss: 3.3414 - val_accuracy: 0.1033
# Epoch 4/30
# 157/157 [==============================] - 5s 31ms/step - loss: 3.3178 - accuracy: 0.1130 - val_loss: 3.3200 - val_accuracy: 0.1102
# Epoch 5/30
# 157/157 [==============================] - 5s 31ms/step - loss: 3.2987 - accuracy: 0.1209 - val_loss: 3.3167 - val_accuracy: 0.1121
# Epoch 6/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.2822 - accuracy: 0.1271 - val_loss: 3.3037 - val_accuracy: 0.1166
# Epoch 7/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.2682 - accuracy: 0.1322 - val_loss: 3.2989 - val_accuracy: 0.1183
# Epoch 8/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.2518 - accuracy: 0.1391 - val_loss: 3.2917 - val_accuracy: 0.1210
# Epoch 9/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.2390 - accuracy: 0.1437 - val_loss: 3.2900 - val_accuracy: 0.1226
# Epoch 10/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.2139 - accuracy: 0.1537 - val_loss: 3.2871 - val_accuracy: 0.1231
# Epoch 11/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.2024 - accuracy: 0.1580 - val_loss: 3.2889 - val_accuracy: 0.1221
# Epoch 12/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.1804 - accuracy: 0.1647 - val_loss: 3.2866 - val_accuracy: 0.1251
# Epoch 13/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.1638 - accuracy: 0.1706 - val_loss: 3.2919 - val_accuracy: 0.1245
# Epoch 14/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.1540 - accuracy: 0.1739 - val_loss: 3.2953 - val_accuracy: 0.1212
# Epoch 15/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.1337 - accuracy: 0.1796 - val_loss: 3.2905 - val_accuracy: 0.1265
# Epoch 16/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.1048 - accuracy: 0.1885 - val_loss: 3.3034 - val_accuracy: 0.1252
# Epoch 17/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.0677 - accuracy: 0.1997 - val_loss: 3.3106 - val_accuracy: 0.1225
# Epoch 18/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.0478 - accuracy: 0.2046 - val_loss: 3.3132 - val_accuracy: 0.1246
# Epoch 19/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.0236 - accuracy: 0.2111 - val_loss: 3.3249 - val_accuracy: 0.1238
# Epoch 20/30
# 157/157 [==============================] - 5s 32ms/step - loss: 3.0003 - accuracy: 0.2172 - val_loss: 3.3638 - val_accuracy: 0.1169
# Epoch 21/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.9950 - accuracy: 0.2176 - val_loss: 3.3668 - val_accuracy: 0.1204
# Epoch 22/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.9586 - accuracy: 0.2260 - val_loss: 3.3744 - val_accuracy: 0.1201
# Epoch 23/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.9374 - accuracy: 0.2316 - val_loss: 3.4078 - val_accuracy: 0.1148
# Epoch 24/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.9158 - accuracy: 0.2350 - val_loss: 3.4039 - val_accuracy: 0.1166
# Epoch 25/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.8840 - accuracy: 0.2430 - val_loss: 3.4185 - val_accuracy: 0.1159
# Epoch 26/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.8630 - accuracy: 0.2463 - val_loss: 3.4438 - val_accuracy: 0.1140
# Epoch 27/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.8533 - accuracy: 0.2477 - val_loss: 3.4745 - val_accuracy: 0.1111
# Epoch 28/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.8184 - accuracy: 0.2554 - val_loss: 3.4878 - val_accuracy: 0.1087
# Epoch 29/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.8139 - accuracy: 0.2557 - val_loss: 3.5286 - val_accuracy: 0.1060
# Epoch 30/30
# 157/157 [==============================] - 5s 32ms/step - loss: 2.7838 - accuracy: 0.2613 - val_loss: 3.5543 - val_accuracy: 0.1063

# %%
plt.plot(1 - np.array(history.history['accuracy']), label='Train_error')
plt.plot(1 - np.array(history.history['val_accuracy']), label = 'val_error')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %% [markdown]
# From the graph we can see that training error decreased continously, while the validation error stopped at around 0.43 after 15 epochs. Now we are going to compare the artificially colored versions of the first 10 images in the test set.

# %%
prediction = model.predict(grayscale_test.reshape(1000, 32, 32, 1))

# %%
prediction = prediction.reshape(1000, 32, 32, k)

# %%
one_hot_encoded_test = one_hot_encoded_test.reshape(1000, 32, 32, k)

# %%
for i in range(0, 9):
    plt.figure(figsize=(20,20))
    plt.subplot(10, 3, 3*i+1)
    plt.imshow(np.dot(prediction[i], centroids).astype(np.uint8))
    plt.subplot(10, 3, 3*i+2)
    plt.imshow(np.dot(one_hot_encoded_test[i], centroids.astype(np.uint8)))
    plt.subplot(10, 3, 3*i+3)
    plt.imshow(X_test[i])
    plt.show()

# %% [markdown]
# From the graph we can see that the artificially colored versions doesn't not maintained the shape of the object well. (It really bad now ...). The tetrachrome image would look better setting, but the colored image still only captures several colors (green and gray)

# %%
def identity_block(X, f, filters, stage, block):
 
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
 
    F1, F2, F3 = filters
 
    X_shortcut = X
 
    X = Conv2D(filters = F1, kernel_size = (1,1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
 
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)
 
    X = Conv2D(filters = F3, kernel_size = (1,1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)
 
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
 
    return X

# %%
# tf.reset_default_graph()
 
with tf.Session() as sess:
    np.random.seed(1)
    A_prev = tf.placeholder("float", [3,4,4,6])
    X = np.random.randn(3,4,4,6)
    A = identity_block(A_prev, f = 2, filters = [2,4,6], stage = 1, block = 'a')
    sess.run(tf.global_variables_initializer())
    out = sess.run([A], feed_dict = {A_prev:X, K.learning_phase():0})
    print("out = " + str(out[0][1][1][0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-391866672731> in <module>
#       1 # tf.reset_default_graph()
#       2
# ----> 3 with tf.Session() as sess:
#       4     np.random.seed(1)
#       5     A_prev = tf.placeholder("float", [3,4,4,6])
#
# AttributeError: module 'tensorflow' has no attribute 'Session'
